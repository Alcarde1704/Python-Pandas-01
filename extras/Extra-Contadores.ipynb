# %%
import pandas as pd

# %%
s = pd.Series(list('asdeasdeasdeasdeasde'))

# %%
s
# Out:
# 0     a
# 1     s
# 2     d
# 3     e
# 4     a
# 5     s
# 6     d
# 7     e
# 8     a
# 9     s
# 10    d
# 11    e
# 12    a
# 13    s
# 14    d
# 15    e
# 16    a
# 17    s
# 18    d
# 19    e
# dtype: object

# %%
s.unique()
# Out:
# array(['a', 's', 'd', 'e'], dtype=object)

# %%
s.value_counts()
# Out:
# a    5
# s    5
# d    5
# e    5
# dtype: int64

# %%
dados = pd.read_csv('../dados/aluguel_residencial.csv', sep=';')

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21726  Apartamento                 Méier        2      0       0    70
# 21727    Quitinete                Centro        0      0       0    27
# 21728  Apartamento           Jacarepaguá        3      1       2    78
# 21729  Apartamento  São Francisco Xavier        2      1       0    48
# 21730  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# ...

# %%
dados['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio',
#        'Casa de Vila'], dtype=object)

# %%
dados['Tipo'].value_counts()
# Out:
# Apartamento           18780
# Casa                    965
# Casa de Condomínio      901
# Quitinete               836
# Casa de Vila            249
# Name: Tipo, dtype: int64

# %% [markdown]
# ## Atividades

# %%
m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
m1
# Out:
# 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'

# %%
eventos = {
            'm1': list(m1),
            'm2': list(m2),
            'm3': list(m3),
            'm4': list(m4),
            'm5': list(m5),
          }

# %%
moedas
# Out:
#    m1 m2 m3 m4 m5
# 0   C  C  C  c  C
# 1   C  C  c  C  C
# 2   c  C  c  C  C
# 3   C  C  C  c  c
# 4   C  C  C  c  C
# 5   c  c  c  C  c
# 6   c  c  c  C  C
# 7   C  C  C  c  c
# 8   C  c  c  c  C
# 9   C  c  C  C  c
# 10  c  C  C  C  C
# 11  c  c  C  c  C
# 12  C  C  C  c  C
# 13  c  C  C  C  c
# 14  C  C  C  C  C
# 15  c  C  C  c  C
# 16  c  c  C  c  c
# 17  C  c  C  c  C
# 18  c  C  C  c  c
# 19  C  c  c  C  C
# 20  c  c  c  c  C
# 21  C  c  c  C  c
# 22  C  c  C  c  c
# 23  C  C  c  C  C
# 24  c  c  c  c  c
# 25  C  c  C  C  C
# 26  C  C  C  c  C
# 27  c  c  C  C  c
# 28  c  c  C  c  c
# 29  c  C  C  C  c
# 30  C  C  C  c  C
# 31  C  c  c  C  c
# 32  c  C  c  C  c
# 33  C  c  C  C  C
# 34  c  c  C  C  C
# 35  C  C  C  c  c
# 36  c  c  c  c  C
# 37  C  C  c  c  c
# 38  c  c  c  c  C
# 39  c  C  C  C  c
# 40  c  C  C  C  C
# 41  C  c  C  C  c
# 42  C  C  c  c  C
# 43  c  c  C  C  c
# 44  C  c  C  C  c
# 45  c  C  c  c  c
# 46  c  c  c  C  c
# 47  c  c  c  C  c
# 48  C  C  C  C  C
# ...

# %%
moedas = pd.DataFrame(eventos)

# %%
moedas['m1'].value_counts()
# Out:
# C    25
# c    25
# Name: m1, dtype: int64

# %%
df = pd.DataFrame(data = [ 'Coroa', 'Cara'], index = ['C', 'c'], columns = ['Faces'])

# %%
df
# Out:
#    Faces
# C  Coroa
# c   Cara

# %%
df['m1'] = moedas['m1'].value_counts().apply(lambda x: x) # esse jeito funcionaria

# %%
del df['m1']

# %%
df
# Out:
#    Faces
# C  Coroa
# c   Cara

# %%
for item in moedas: # utilizando o for a cada item se torna a cada coluna dentro de moedas
    df = pd.concat([df, moedas[item].value_counts()], axis=1)

# %%
df
# Out:
#    Faces  m1  m2  m3  m4  m5
# C  Coroa  25  24  31  27  25
# c   Cara  25  26  19  23  25
