# %% [markdown]
# # Relatório de análise V

# %% [markdown]
# ## tratamento de dados faltantes

# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/aluguel_residencial.csv', sep=';')

# %%
df.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# ...

# %%
df.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False   True
# 4      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 22575  False   False    False  False   False  False  False       False  False
# 22576  False   False    False  False   False  False  False       False  False
# 22577  False   False    False  False   False  False  False       False  False
# 22578  False   False    False  False   False  False  False       False  False
# 22579  False   False    False  False   False  False  False       False   True
#
# [22580 rows x 9 columns]

# %%
df.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio   IPTU
# 0      True    True     True   True    True  True   True        True   True
# 1      True    True     True   True    True  True   True       False  False
# 2      True    True     True   True    True  True   True        True   True
# 3      True    True     True   True    True  True   True        True  False
# 4      True    True     True   True    True  True   True       False  False
# ...     ...     ...      ...    ...     ...   ...    ...         ...    ...
# 22575  True    True     True   True    True  True   True        True   True
# 22576  True    True     True   True    True  True   True        True   True
# 22577  True    True     True   True    True  True   True        True   True
# 22578  True    True     True   True    True  True   True        True   True
# 22579  True    True     True   True    True  True   True        True  False
#
# [22580 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22580 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22580 non-null  object
#  1   Bairro      22580 non-null  object
#  2   Quartos     22580 non-null  int64
#  3   Vagas       22580 non-null  int64
#  4   Suites      22580 non-null  int64
#  5   Area        22580 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  20765 non-null  float64
#  8   IPTU        15795 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
df[df['Valor'].isnull()]
# Out:
#              Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 58    Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 1492  Apartamento             Leme        2      0       0    75    NaN
# 1683         Casa     Campo Grande        3      4       3   363    NaN
# 2012  Apartamento         Botafogo        2      0       0    95    NaN
# 2034  Apartamento       Copacabana        2      0       0    72    NaN
# 4941         Casa     Campo Grande        3      2       1   100    NaN
# 8568  Apartamento             Leme        2      0       1    75    NaN
# 8947  Apartamento           Glória        3      0       1   135    NaN
# 9149  Apartamento            Gávea        3      1       1   105    NaN
#
#       Condominio   IPTU
# 58         970.0   68.0
# 1492       878.0    NaN
# 1683         NaN    NaN
# 2012      1010.0  170.0
# 2034       850.0    NaN
# 4941         NaN    NaN
# 8568       878.0    NaN
# 8947       910.0  228.0
# ...

# %%
A = df.shape[0]
df.dropna(subset=['Valor'], inplace=True)
B = df.shape[0]

# %%
A - B
# Out:
# 9

# %%
df[df['Valor'].isnull()] ## apaguei os valores nulos de Valor
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22571 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22571 non-null  object
#  1   Bairro      22571 non-null  object
#  2   Quartos     22571 non-null  int64
#  3   Vagas       22571 non-null  int64
#  4   Suites      22571 non-null  int64
#  5   Area        22571 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  20758 non-null  float64
#  8   IPTU        15791 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Analisando Condominio

# %%
df[df['Condominio'].isnull()]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 4             Apartamento              Vista Alegre        3      1       0
# 6      Casa de Condomínio           Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                     Ramos        2      2       0
# 8             Apartamento                    Centro        1      0       0
# ...                   ...                       ...      ...    ...     ...
# 22510                Casa              Campo Grande        1      0       0
# 22516        Casa de Vila                    Pavuna        2      0       0
# 22535                Casa  Recreio dos Bandeirantes        4      2       2
# 22547                Casa             Bento Ribeiro        2      1       0
# 22558                Casa                    Centro        5      0       1
#
#        Area    Valor  Condominio  IPTU
# ...

# %% [markdown]
# ## Casa de condominio e apartamento não pode ter registros com Nulos

# %%
selecao = (df['Tipo'] == 'Apartamento') & (df['Condominio'].isnull()) ## necessário para o tratamento condicional criar a series booleana

# %%
selecao
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 22575    False
# 22576    False
# 22577    False
# 22578    False
# 22579    False
# Length: 22571, dtype: bool

# %%
df = df[~selecao]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21826 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        21826 non-null  object
#  1   Bairro      21826 non-null  object
#  2   Quartos     21826 non-null  int64
#  3   Vagas       21826 non-null  int64
#  4   Suites      21826 non-null  int64
#  5   Area        21826 non-null  int64
#  6   Valor       21826 non-null  float64
#  7   Condominio  20758 non-null  float64
#  8   IPTU        15685 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
selecao = (df['Tipo'] == 'Casa de Condomínio') & (df['Condominio'].isnull())

# %%
selecao
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 22575    False
# 22576    False
# 22577    False
# 22578    False
# 22579    False
# Length: 21826, dtype: bool

# %%
df = df[~selecao]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21731 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        21731 non-null  object
#  1   Bairro      21731 non-null  object
#  2   Quartos     21731 non-null  int64
#  3   Vagas       21731 non-null  int64
#  4   Suites      21731 non-null  int64
#  5   Area        21731 non-null  int64
#  6   Valor       21731 non-null  float64
#  7   Condominio  20758 non-null  float64
#  8   IPTU        15670 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
df[(df['Tipo'] == 'Apartamento') & (df['Condominio'].isnull())]  ## nao possui mais registros de apartamento sem condominio
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df[(df['Tipo'] == 'Casa de Condomínio') & (df['Condominio'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ## Limpado os dados de Apartamento e Casa de Condominio com Condominio Nulos

# %% [markdown]
# ## tratamento de dados faltando pt 2

# %%
df[df['Condominio'].isnull()].shape[0] ## numero de nulos e nao posso ter nulos preciso que sejam 0
# Out:
# 973

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21731 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        21731 non-null  object
#  1   Bairro      21731 non-null  object
#  2   Quartos     21731 non-null  int64
#  3   Vagas       21731 non-null  int64
#  4   Suites      21731 non-null  int64
#  5   Area        21731 non-null  int64
#  6   Valor       21731 non-null  float64
#  7   Condominio  20758 non-null  float64
#  8   IPTU        15670 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
df = df.fillna({'Condominio': 0, 'IPTU': 0}) ## vai completar os nulos com o valor que eu quiser

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21731 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        21731 non-null  object
#  1   Bairro      21731 non-null  object
#  2   Quartos     21731 non-null  int64
#  3   Vagas       21731 non-null  int64
#  4   Suites      21731 non-null  int64
#  5   Area        21731 non-null  int64
#  6   Valor       21731 non-null  float64
#  7   Condominio  21731 non-null  float64
#  8   IPTU        21731 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
df
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %%
df[df['IPTU'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.to_csv('../dados/aluguel_residencial.csv', sep=';', index=False)

# %% [markdown]
# ## Atividades Praticas

# %%
imoveis = pd.DataFrame([['Apartamento', None, 970, 68], 
                        ['Apartamento', 2000, 878, 112], 
                        ['Casa', 5000, None, 500], 
                        ['Apartamento', None, 1010, 170], 
                        ['Apartamento', 1500, 850, None], 
                        ['Casa', None, None, None], 
                        ['Apartamento', 2000, 878, None], 
                        ['Apartamento', 1550, None, 228], 
                        ['Apartamento', 2500, 880, 195]], 
                        columns = ['Tipo', 'Valor', 'Condominio', 'IPTU'])

# %%
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento     NaN       970.0   68.0
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 3  Apartamento     NaN      1010.0  170.0
# 4  Apartamento  1500.0       850.0    NaN
# 5         Casa     NaN         NaN    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis.dropna(subset=['Valor'], inplace=True)

# %%
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 4  Apartamento  1500.0       850.0    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
selecao = (imoveis['Tipo'] == 'Apartamento') & (imoveis['Condominio'].isnull())

# %%
selecao
# Out:
# 1    False
# 2    False
# 4    False
# 6    False
# 7     True
# 8    False
# dtype: bool

# %%
imoveis = imoveis[~selecao]
# Out:
# C:\Users\Diogo\AppData\Local\Temp\ipykernel_8488\1993132710.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   imoveis = imoveis[~selecao]

# %%
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 4  Apartamento  1500.0       850.0    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis = imoveis.fillna({'Condominio': 0, 'IPTU': 0})

# %%
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         0.0  500.0
# 4  Apartamento  1500.0       850.0    0.0
# 6  Apartamento  2000.0       878.0    0.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis.index = range(imoveis.shape[0])

# %%
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento  2000.0       878.0  112.0
# 1         Casa  5000.0         0.0  500.0
# 2  Apartamento  1500.0       850.0    0.0
# 3  Apartamento  2000.0       878.0    0.0
# 4  Apartamento  2500.0       880.0  195.0
